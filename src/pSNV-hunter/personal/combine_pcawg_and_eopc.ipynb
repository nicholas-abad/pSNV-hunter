# %%
import pandas as pd

# %%
pcawg_results = pd.read_csv("/Users/nicholasabad/Desktop/workspace/data/_DATA_FOR_PAPER_/SupplementaryTables/1_remaining_mutations_top1000_28Feb2024.csv")
pcawg_results
# Out:
#      score                                   pid   cohort #CHROM        POS  \
# 0    93.45  45a7949d-e63f-4956-866c-df51257032de  BLCA-US      2   71204529
# 1    93.41  6c884037-49f9-41c3-b0e5-9cbcd545aeb7  SKCM-US      9   91933357
# 2    88.10  49dec0c2-8e75-4f44-a253-82b2ea605890  LUAD-US      2   71204529
# 3    86.45  d692ecd0-2433-426b-9af2-a30c44a80f7c  THCA-US      5    1295228
# 4    86.30  9988eb07-01f6-4f83-8699-bb63e0525f08  HNSC-US      7  145813786
# ..     ...                                   ...      ...    ...        ...
# 995  52.10  14c5b81d-da49-4db1-9834-77711c2b1d38  READ-US      1  226497910
# 996  52.09  3869ff3f-21b9-4817-8ff4-83c6fc75ab11  SKCM-US     11   16634625
# 997  52.08  2bff30d5-be79-4686-8164-7a7d9619d3c0  LIHC-US      6   43423946
# 998  52.08  b07bad52-d44c-4b27-900a-960985bfadec  SKCM-US      2   28113539
# 999  52.07  f5c8f98a-c34a-49e8-a655-d8f29487b55c  CLLE-ES      1  224517711
#
# ...

# %%
pcawg_results.columns
# Out:
# Index(['score', 'pid', 'cohort', '#CHROM', 'POS', 'GENE', 'SEQUENCE_CONTEXT',
#        'REF', 'ALT', 'strand', 'FPKM', 'FPKM_Z_score', 'cn_score',
#        'within_cgc_list', 'open_chromatin', 'allele_frequency',
#        'ICGC_Estimated_Purity',
#        'num_created_tfs_passing_tf_expression_threshold',
#        'created_tfs_passing_tf_expression_threshold',
#        'num_destroyed_tfs_passing_tf_expression_threshold',
#        'destroyed_tfs_passing_tf_expression_threshold', 'num_remaining_tfs',
#        'remaining_tfs',
#        'JASPAR2020_CORE_vertebrates_non_redundant(tf_name,binding_affinity,seq1,seq2,raw,zscore,log,tf_sequence_logo)',
#        'paths_with_recurrence(format=path,pid,cohort,bp,ref,alt,gene,chr,raw_score,zscore,log_score,confidence,purity,af,(tfs_seperated_by_//))',
#        'num_original_mutations', 'num_final_mutations',
#        'num_promoter_mutations', 'num_recurrent_mutations'],
#       dtype='object')

# %%
pcawg_results[(pcawg_results["within_cgc_list"] == False) & (pcawg_results["open_chromatin"] == False)][["REF", "ALT", "POS", "GENE", "within_cgc_list", "open_chromatin", "ICGC_Estimated_Purity", "allele_frequency"]]
# Out:
#     REF ALT        POS        GENE  within_cgc_list  open_chromatin  \
# 80    G   A  106330240       IGHJ6            False           False
# 113   C   T  106329752       IGHJ6            False           False
# 143   G   A   49990694      RPL13A            False           False
# 164   C   T   61735191        FTH1            False           False
# 222   C   T  109541735       RPL34            False           False
# 224   G   A   43824529       CDC20            False           False
# 296   G   A   43824528       CDC20            False           False
# 338   G   A  175036341         TNN            False           False
# 351   C   T   17830242       MAP1S            False           False
# 364   G   A    1340837       UVSSA            False           False
# 463   G   A   54582889       SMUG1            False           False
# 493   G   A  106329550       IGHJ6            False           False
# 496   C   T   45973318         SP2            False           False
# ...

# %%
eopc = pd.read_csv("/Users/nicholasabad/Desktop/workspace/REMIND-Cancer-visualization/my_data/2_eopc_de_remaining_mutations_28Feb2024.csv")
eopc
# Out:
#     score                                   pid   cohort  #CHROM        POS  \
# 0   69.75  3c92c0e9-68e0-4354-8ed1-b6506878145d  EOPC-DE       6  135501964
# 1   55.94  f601cf2f-081f-484d-ab0e-21a8ec8d3770  EOPC-DE       5  149535916
# 2   55.32  bd3028c7-1fde-401d-a6b2-5f8e61eb4aa1  EOPC-DE       1   35658770
# 3   48.50  f601cf2f-081f-484d-ab0e-21a8ec8d3770  EOPC-DE      10   47083700
# 4   47.24  ad007b59-46f6-48b9-958a-2b9d28cca3b7  EOPC-DE       7   25021762
# 5   46.64  8930735a-4eb4-4489-8513-d4b600c316ab  EOPC-DE       1   59762769
# 6   45.76  ad007b59-46f6-48b9-958a-2b9d28cca3b7  EOPC-DE      21   34852696
# 7   43.07  dd5ed858-0623-4387-b1bf-109175c32ef4  EOPC-DE      11   71164310
# 8   41.80  6fe135ef-54b4-4941-9bb9-872dc4d18d9f  EOPC-DE      19   30155489
# 9   39.74  1be81ade-7ad6-4e7e-90d0-f986b3fb0a25  EOPC-DE      12    6486602
# 10  39.39  f601cf2f-081f-484d-ab0e-21a8ec8d3770  EOPC-DE      15   59226203
# ...

# %%
combined = pd.concat([pcawg_top200, eopc]).reset_index(drop=True).sort_values("score", ascending=False).iloc[:200]

# %%
combined[combined["GENE"] == "MYB"]
# Out:
#      score                                   pid   cohort #CHROM        POS  \
# 200  69.75  3c92c0e9-68e0-4354-8ed1-b6506878145d  EOPC-DE      6  135501964
#
#     GENE REF ALT strand   FPKM  ... num_recurrent_mutations expression_traces  \
# 200  MYB   C   A      +  14.56  ...                     0.0               NaN
#
#      tf_summary  ncbi_gene_summary  ncbi_url in_old_results cn_score.1  \
# 200         NaN                NaN       NaN            NaN        NaN
#
#     cn_file_of_score ICGC_Estimated_Purity.1  open_chromatin
# 200              NaN                     NaN            True
#
# [1 rows x 167 columns]

# %%
list(eopc.columns)
# Out:
# ['score',
#  'pid',
#  'cohort',
#  '#CHROM',
#  'POS',
#  'GENE',
#  'SEQUENCE_CONTEXT',
#  'REF',
#  'ALT',
#  'strand',
#  'FPKM',
#  'FPKM_Z_score',
#  'within_cgc_list',
#  'open_chromatin',
#  'allele_frequency',
#  'ICGC_Estimated_Purity',
#  'num_created_tfs_passing_tf_expression_threshold',
#  'created_tfs_passing_tf_expression_threshold',
#  'num_destroyed_tfs_passing_tf_expression_threshold',
#  'destroyed_tfs_passing_tf_expression_threshold',
#  'num_remaining_tfs',
#  'remaining_tfs',
#  'JASPAR2020_CORE_vertebrates_non_redundant(tf_name,binding_affinity,seq1,seq2,raw,zscore,log,tf_sequence_logo)',
#  'paths_with_recurrence(format=path,pid,cohort,bp,ref,alt,gene,chr,raw_score,zscore,log_score,confidence,purity,af,(tfs_seperated_by_//))',
#  'num_original_mutations',
#  'num_final_mutations',
#  'num_promoter_mutations',
#  'num_recurrent_mutations']

# %%
eopc["ICGC_Estimated_Purity"]
# Out:
# 0     0.590
# 1     0.530
# 2     0.462
# 3     0.530
# 4     0.300
# 5     0.290
# 6     0.300
# 7     0.563
# 8     0.460
# 9     0.369
# 10    0.530
# 11    0.300
# 12    0.710
# 13    0.300
# 14    0.669
# 15    0.710
# 16    0.530
# 17    0.501
# 18    0.710
# 19    0.530
# 20    0.300
# 21    0.530
# 22    0.610
# 23    0.305
# 24    0.462
# 25    0.305
# 26    0.499
# 27    0.300
# 28    0.499
# 29    0.530
# 30    0.300
# 31    0.460
# 32    0.499
# 33    0.530
# 34    0.530
# 35    0.290
# 36    0.300
# 37    0.530
# 38    0.530
# 39    0.530
# 40    0.501
# 41    0.579
# 42    0.300
# 43    0.501
# 44    0.549
# 45    0.300
# 46    0.530
# 47    0.530
# 48    0.300
# 49    0.610
# 50    0.369
# 51    0.549
# 52    0.610
# 53    0.610
# Name: ICGC_Estimated_Purity, dtype: float64
